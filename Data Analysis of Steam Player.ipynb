# %% [markdown]
# **Importing Libraries and Datasets of Steam Player**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import datetime as dt
sns.set_style('darkgrid')

df = pd.read_csv('C:/Users/SOUBHIK MANDAL/Desktop/jupyter notebook/Data Analysis of Steam Player/Valve_Player_Data.csv')
df
# Out:
#           Month_Year  Avg_players       Gain Percent_Gain  Peak_Players  \
# 0     September 2021    512350.92     268.96       +0.05%        942519
# 1        August 2021    512081.96    6014.60       +1.19%        802544
# 2          July 2021    506067.36  -43279.72       -7.88%        763523
# 3          June 2021    549347.08 -110541.81      -16.75%        929940
# 4           May 2021    659888.89  -63457.63       -8.77%       1087197
# ...              ...          ...        ...          ...           ...
# 5266   December 2016       192.03     -21.90      -10.24%           405
# 5267   November 2016       213.92    -134.68      -38.63%           537
# 5268    October 2016       348.60    -201.75      -36.66%          1031
# 5269  September 2016       550.36     543.26    +7654.89%          2836
# 5270     August 2016         7.10        NaN          NaN            18
#
#                                      URL        Date  \
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#          Month_Year  Avg_players  Gain Percent_Gain  Peak_Players  \
# 110       July 2012       932.57   NaN          NaN          1642
# 221       July 2012     52721.05   NaN          NaN         75041
# 276      March 2017     17551.14   NaN          NaN         67846
# 287   November 2020     74957.26   NaN          NaN        117193
# 398       July 2012     45566.90   NaN          NaN         62321
# ...             ...          ...   ...          ...           ...
# 5061      June 2020       870.49   NaN          NaN          1646
# 5141  February 2015     12871.38   NaN          NaN         45770
# 5192      June 2017         0.08   NaN          NaN             2
# 5208      June 2020      2585.63   NaN          NaN          3793
# 5270    August 2016         7.10   NaN          NaN            18
#
#                                       URL        Date  \
# 110       https://steamcharts.com/app/730  2012-07-01
# 221       https://steamcharts.com/app/570  2012-07-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5271 entries, 0 to 5270
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Month_Year    5271 non-null   object
#  1   Avg_players   5271 non-null   float64
#  2   Gain          5173 non-null   float64
#  3   Percent_Gain  5173 non-null   object
#  4   Peak_Players  5271 non-null   int64
#  5   URL           5271 non-null   object
#  6   Date          5271 non-null   object
#  7   Game_Name     5271 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 329.6+ KB

# %%
df['Game_Name'].unique()
# Out:
# array(['Counter Strike: Global Offensive', 'Dota 2',
#        'PUBG: Battlegrounds', 'Apex Legends', 'Team Fortress 2',
#        'Grand Theft Auto V', 'NARAKA: BLADEPOINT', 'Wallpaper Engine',
#        'Rust', 'Destiny 2', 'Warframe', 'Cookie Clicker',
#        "Tom Clancy's Rainbow Six Seige", 'Football Manager 2021 ',
#        'PAYDAY 2', 'ARK: Survival Evolved', 'Dead by Daylight',
#        "Sid Meier's Civilization VI", 'MIR4', 'Unturned', 'Terraria',
#        'War Thunder', 'Hearts of Iron IV', 'Battlefield V', 'Valheim',
#        'World of Tanks Blitz', 'Dayz', 'Total War: WARHAMMER II',
#        "Don't Starve Together", 'Euro Truck Simulator 2', 'Rocket League',
#        "Garry's Mod", 'Monster Hunter: World', 'Stardew Valley',
#        'FINAL FANTASY XIV Online', 'Bless Unleashed ',
#        'The Witcher 3: Wild Hunt', '雀魂麻将(MahjongSoul)', 'RimWorld',
#        'Red Dead Redemption 2', '7 Days to Die', 'Black Desert',
#        'Cities: Skylines', "Sid Meier's Civilization V",
# ...

# %% [markdown]
# **Top 10 Game of 2021**

# %%
df2 = df
df2['Date'] = pd.to_datetime(df2['Date'])
df2_2021 = df2[df2['Date'].dt.year == 2021]
top10_peak_2021 = df2_2021[['Game_Name', 'Peak_Players']].groupby('Game_Name') \
                                                                    .sum() \
                                                                    .sort_values('Peak_Players', ascending=False) \
                                                                    .head(10)
top10_avg_2021 = df2_2021[['Game_Name', 'Avg_players']].groupby('Game_Name') \
                                                                    .sum() \
                                                                    .sort_values('Avg_players', ascending=False) \
                                                                    .head(10)
fig, axes = plt.subplots(2, figsize=(10, 12))
fig.suptitle('Top 10 Game in 2021')
sns.barplot(ax=axes[0], data=top10_peak_2021, x='Peak_Players', y=top10_peak_2021.index)
axes[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000) + 'K'))
axes[0].set(title='Highest peak players', xlabel='Peak Players', ylabel='Game Name')
sns.barplot(ax=axes[1], data=top10_avg_2021, x='Avg_players', y=top10_avg_2021.index)
axes[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000) + 'K'))
axes[1].set(title='Highest average players', xlabel='Average Players', ylabel='Game Name')
# Out:
# [Text(0.5, 1.0, 'Highest average players'),
#  Text(0.5, 0, 'Average Players'),
#  Text(0, 0.5, 'Game Name')]

# %% [markdown]
# We can observe that games rank 1 to 9 for both 'Average' and 'Peak' players are the same. There is only one difference in the last ranking.

# %% [markdown]
# **Average Player by Months**

# %%
top10 = df2[df2['Game_Name'].isin(top10_avg_2021.index)]
top10
# Out:
#           Month_Year  Avg_players       Gain Percent_Gain  Peak_Players  \
# 0     September 2021    512350.92     268.96       +0.05%        942519
# 1        August 2021    512081.96    6014.60       +1.19%        802544
# 2          July 2021    506067.36  -43279.72       -7.88%        763523
# 3          June 2021    549347.08 -110541.81      -16.75%        929940
# 4           May 2021    659888.89  -63457.63       -8.77%       1087197
# ...              ...          ...        ...          ...           ...
# 1544       June 2021     20198.47  -14691.69      -42.11%         37931
# 1545        May 2021     34890.17  -34476.85      -49.70%         80466
# 1546      April 2021     69367.02 -109068.42      -61.12%        159037
# 1547      March 2021    178435.44  -31866.80      -15.15%        405826
# 1548   February 2021    210302.24        NaN          NaN        498478
#
#                                      URL       Date  \
# ...

# %%
top10 =top10.sort_values(by="Date")
top10
# Out:
#          Month_Year  Avg_players      Gain Percent_Gain  Peak_Players  \
# 398       July 2012     45566.90       NaN          NaN         62321
# 221       July 2012     52721.05       NaN          NaN         75041
# 110       July 2012       932.57       NaN          NaN          1642
# 397     August 2012     61561.37  15994.47      +35.10%        117917
# 109     August 2012     15475.39  14542.81    +1559.43%         52261
# ..              ...          ...       ...          ...           ...
# 399  September 2021     81232.20 -37668.37      -31.68%        151408
# 540  September 2021     69502.99 -13829.21      -16.60%        122359
# 634  September 2021     89845.19  32606.68      +56.97%        147513
# 111  September 2021    391082.08 -33898.09       -7.98%        666838
# 0    September 2021    512350.92    268.96       +0.05%        942519
#
#                                      URL       Date  \
# 398      https://steamcharts.com/app/440 2012-07-01
# ...

# %%
fig, axes = plt.subplots(2, figsize=(20, 18))
fig.suptitle('Average Player By Month')
sns.lineplot(ax=axes[0], data=top10, x='Date', y='Avg_players', hue='Game_Name')
axes[0].yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000) + 'K'))
axes[0].tick_params(axis='x', rotation=90)
axes[0].set(ylabel='Avg Player')
sns.lineplot(ax=axes[1], data=top10, x='Date', y='Avg_players', hue='Game_Name')
axes[1].tick_params(axis='x', rotation=90)
axes[1].set(ylabel='Avg Player (log)', yscale='log')
# Out:
# [Text(0, 0.5, 'Avg Player (log)'), None]

# %% [markdown]
# Between 2017 and 2018, the average number of PUBG players climbed dramatically, according to the graph. The average PUBG player began to fall after 2018. The typical Dota2 and CSGO gamer, on the other hand, is steadily increasing. The average Dota2 and CSGO player has remained consistent since 2015. Keeping everyone at home in the Covid-19 scenario in early 2021 greatly boosted the number of players.

# %% [markdown]
# **Data Visulatization of Top 10 Game players of 2021**

# %%
top10['Game_Name'].unique()
# Out:
# array(['Team Fortress 2', 'Dota 2', 'Counter Strike: Global Offensive',
#        'Rust', 'Grand Theft Auto V', "Tom Clancy's Rainbow Six Seige",
#        'PUBG: Battlegrounds', 'Destiny 2', 'Apex Legends', 'Valheim'],
#       dtype=object)

# %%
#Team Fortress 2
TF2 = df[df['Game_Name'] == 'Team Fortress 2'].sort_values(by="Date")
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.lineplot(data=TF2,  x="Month_Year", y="Peak_Players")
plt.xticks(rotation=90)
plt.title('Peak Player of Team Fortress 2')
plt.subplot(1, 2, 2)
sns.lineplot(data=TF2,  x="Month_Year", y="Avg_players")
plt.xticks(rotation=90)
plt.title('Average players of Team Fortress 2')
# Out:
# Text(0.5, 1.0, 'Average players of Team Fortress 2')

# %%
#Dota 2
Dota = df[df['Game_Name'] == 'Dota 2'].sort_values(by="Date")
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.lineplot(data=Dota,  x="Month_Year", y="Peak_Players")
plt.xticks(rotation=90)
plt.title('Peak Player of Dota 2')
plt.subplot(1, 2, 2)
sns.lineplot(data=Dota,  x="Month_Year", y="Avg_players")
plt.xticks(rotation=90)
plt.title('Average players of Dota 2')
# Out:
# Text(0.5, 1.0, 'Average players of Dota 2')

# %%
#Counter Strike: Global Offensive
CSGO = df[df['Game_Name'] == 'Counter Strike: Global Offensive'].sort_values(by="Date")
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.lineplot(data=CSGO,  x="Month_Year", y="Peak_Players")
plt.xticks(rotation=90)
plt.title('Peak Player of Counter Strike: Global Offensive')
plt.subplot(1, 2, 2)
sns.lineplot(data=CSGO,  x="Month_Year", y="Avg_players")
plt.xticks(rotation=90)
plt.title('Average players of Counter Strike: Global Offensive')
# Out:
# Text(0.5, 1.0, 'Average players of Counter Strike: Global Offensive')

# %%
#Rust
Rust = df[df['Game_Name'] == 'Rust'].sort_values(by="Date")
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.lineplot(data=Rust,  x="Month_Year", y="Peak_Players")
plt.xticks(rotation=90)
plt.title('Peak Player of Rust')
plt.subplot(1, 2, 2)
sns.lineplot(data=Rust,  x="Month_Year", y="Avg_players")
plt.xticks(rotation=90)
plt.title('Average players of Rust')
# Out:
# Text(0.5, 1.0, 'Average players of Rust')

# %%
#Grand Theft Auto V
GTA5 = df[df['Game_Name'] == 'Grand Theft Auto V'].sort_values(by="Date")
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.lineplot(data=GTA5,  x="Month_Year", y="Peak_Players")
plt.xticks(rotation=90)
plt.title('Peak Player of Grand Theft Auto V')
plt.subplot(1, 2, 2)
sns.lineplot(data=GTA5,  x="Month_Year", y="Avg_players")
plt.xticks(rotation=90)
plt.title('Average players of Grand Theft Auto V')
# Out:
# Text(0.5, 1.0, 'Average players of Grand Theft Auto V')

# %%
#ARK: Survival Evolved
ARK = df[df['Game_Name'] == 'ARK: Survival Evolved'].sort_values(by="Date")
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.lineplot(data=ARK,  x="Month_Year", y="Peak_Players")
plt.xticks(rotation=90)
plt.title('Peak Player of ARK: Survival Evolved')
plt.subplot(1, 2, 2)
sns.lineplot(data=ARK,  x="Month_Year", y="Avg_players")
plt.xticks(rotation=90)
plt.title('Average players of ARK: Survival Evolved')
# Out:
# Text(0.5, 1.0, 'Average players of ARK: Survival Evolved')

# %%
#PUBG: Battlegrounds
PUBG = df[df['Game_Name'] == 'PUBG: Battlegrounds'].sort_values(by="Date")
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.lineplot(data=PUBG,  x="Month_Year", y="Peak_Players")
plt.xticks(rotation=90)
plt.title('Peak Player of PUBG: Battlegrounds')
plt.subplot(1, 2, 2)
sns.lineplot(data=PUBG,  x="Month_Year", y="Avg_players")
plt.xticks(rotation=90)
plt.title('Average players of PUBG: Battlegrounds')
# Out:
# Text(0.5, 1.0, 'Average players of PUBG: Battlegrounds')

# %%
#Destiny 2
D2 = df[df['Game_Name'] == 'Destiny 2'].sort_values(by="Date")
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.lineplot(data=D2,  x="Month_Year", y="Peak_Players")
plt.xticks(rotation=90)
plt.title('Peak Player of Destiny 2')
plt.subplot(1, 2, 2)
sns.lineplot(data=D2,  x="Month_Year", y="Avg_players")
plt.xticks(rotation=90)
plt.title('Average players of Destiny 2')
# Out:
# Text(0.5, 1.0, 'Average players of Destiny 2')

# %%
#Apex Legends
AL = df[df['Game_Name'] == 'Apex Legends'].sort_values(by="Date")
plt.figure(figsize=(18,6))
plt.subplot(1, 2, 1)
sns.lineplot(data=AL,  x="Month_Year", y="Peak_Players")
plt.xticks(rotation=90)
plt.title('Peak Player of Apex Legends')
plt.subplot(1, 2, 2)
sns.lineplot(data=AL,  x="Month_Year", y="Avg_players")
plt.xticks(rotation=90)
plt.title('Average players of Apex Legends')
# Out:
# Text(0.5, 1.0, 'Average players of Apex Legends')
